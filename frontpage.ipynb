# %%
import flask
app = flask.Flask(__name__)
@app.route("/")
def hello():
    return "Hello World!"
@app.route('/greet/<name>')
def greet(name):
    '''Say hello to your first parameter'''
    return "Hello, %s!" %name
#-------- MODEL GOES HERE -----------#
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
df = pd.read_csv('./titanic.csv')
include = ['Pclass', 'Sex', 'Age', 'Fare', 'SibSp', 'Survived']
# Create dummies and drop NaNs
df['Sex'] = df['Sex'].apply(lambda x: 0 if x == 'male' else 1)
df = df[include].dropna()
X = df[['Pclass', 'Sex', 'Age', 'Fare', 'SibSp']]
y = df['Survived']
PREDICTOR = RandomForestClassifier(n_estimators=100).fit(X, y)
#-------- ROUTES GO HERE -----------#
@app.route('/predict', methods=["GET"])
def predict():
    pclass = flask.request.args['pclass']
    sex = flask.request.args['sex']
    age = flask.request.args['age']
    fare = flask.request.args['fare']
    sibsp = flask.request.args['sibsp']
    item = np.array([pclass, sex, age, fare, sibsp]).reshape(1,-1)
    score = PREDICTOR.predict_proba(item)
    results = {'survival chances': score[0,1], 'death chances': score[0,0]}
    return flask.jsonify(results)
@app.route('/page')
def page():
    with open("RecommenderLanding.html", 'r') as viz_file:
        return viz_file.read()
    
@app.route('/index')
def index():
    user = {'username': 'Miguel'}
    return render_template('RecommenderLanding.html', title='Home', user=user)
    
    
from flask import request
@app.route('/result', methods=["POST"])
def result():
    '''Gets prediction using the HTML form'''
    if flask.request.method == "POST":
        inputs = request.form
        pclass = inputs['pclass'][0]
        sex = inputs['sex'][0]
        age = inputs['age'][0]
        fare = inputs['fare'][0]
        sibsp = inputs['sibsp'][0]
        item = np.array([pclass, sex, age, fare, sibsp]).reshape(1,-1)
        score = PREDICTOR.predict_proba(item)
        results = {'survival chances': score[0,1], 'death chances': score[0,0]}
        return flask.jsonify(results)
if __name__ == '__main__':
    '''Connects to the server'''
    HOST = '127.0.0.1'
    PORT = 5000
    app.run(HOST, PORT)

# %%
import flask
app = flask.Flask(__name__)

#-------- MODEL GOES HERE -----------#
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
df = pd.read_csv('./titanic.csv')
include = ['Pclass', 'Sex', 'Age', 'Fare', 'SibSp', 'Survived']
# Create dummies and drop NaNs
df['Sex'] = df['Sex'].apply(lambda x: 0 if x == 'male' else 1)
df = df[include].dropna()
X = df[['Pclass', 'Sex', 'Age', 'Fare', 'SibSp']]
y = df['Survived']
PREDICTOR = RandomForestClassifier(n_estimators=100).fit(X, y)
#-------- ROUTES GO HERE -----------#

@app.route("/")
def hello():
    return "Hello World!"

@app.route('/index')
def index():
    user = {'username': 'Miguel'}
    return render_template("RecommenderLanding.html")


@app.route('/page')
def page():
    with open("RecommenderLanding.html", 'r') as viz_file:
        return viz_file.read()

@app.route('/greet/<name>')
def greet(name):
    '''Say hello to your first parameter'''
    return "Hello, %s!" %name

from flask import request
@app.route('/result', methods=["POST"])
def result():
    '''Gets prediction using the HTML form'''
    if flask.request.method == "POST":
        inputs = request.form
        pclass = inputs['pclass'][0]
        sex = inputs['sex'][0]
        age = inputs['age'][0]
        fare = inputs['fare'][0]
        sibsp = inputs['sibsp'][0]
        item = np.array([pclass, sex, age, fare, sibsp]).reshape(1,-1)
        score = PREDICTOR.predict_proba(item)
        results = {'survival chances': score[0,1], 'death chances': score[0,0]}
        return flask.jsonify(results)

#-------- init  GO HERE -----------#
if __name__ == '__main__':
    '''Connects to the server'''
    HOST = '127.0.0.1'
    PORT = 5001
    app.run(HOST, PORT)

    #app.run()
# Out:
#  * Running on http://127.0.0.1:5001/ (Press CTRL+C to quit)
# 127.0.0.1 - - [08/Sep/2018 13:27:25] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2018 13:27:52] "GET /page HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2018 13:27:52] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 13:27:52] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 13:29:07] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2018 13:29:10] "GET /page HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2018 13:29:10] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 13:29:10] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 13:29:32] "POST /result HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2018 13:29:32] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 13:53:03] "GET /page HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2018 13:53:03] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 13:53:03] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 13:55:32] "GET /page HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2018 13:55:33] "GET /spectre.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 13:55:33] "GET /spectre-exp.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 13:55:33] "GET /spectre-icons.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 13:55:33] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 13:55:33] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 13:56:29] "GET /page HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2018 13:56:29] "GET /spectre.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 13:56:29] "GET /spectre-exp.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 13:56:29] "GET /spectre-icons.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 13:56:29] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 13:56:29] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 15:35:26] "GET /page HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2018 15:35:26] "GET /spectre.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 15:35:26] "GET /spectre-exp.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 15:35:26] "GET /spectre-icons.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 15:35:26] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 15:35:26] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 15:36:04] "GET /page HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2018 15:36:04] "GET /spectre.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 15:36:04] "GET /spectre-exp.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 15:36:04] "GET /spectre-icons.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 15:36:04] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 15:36:04] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:29:22] "GET /page HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2018 19:29:22] "GET /spectre.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:29:22] "GET /spectre-exp.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:29:22] "GET /spectre-icons.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:29:22] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:29:22] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:31:42] "GET /page HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2018 19:31:42] "GET /spectre.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:31:42] "GET /spectre-exp.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:31:42] "GET /spectre-icons.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:31:42] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:31:42] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:32:14] "GET /page HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2018 19:32:14] "GET /spectre.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:32:14] "GET /spectre-exp.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:32:14] "GET /spectre-icons.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:32:14] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:32:14] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:33:22] "GET /page HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2018 19:33:22] "GET /spectre.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:33:22] "GET /spectre-exp.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:33:22] "GET /spectre-icons.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:33:22] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:33:22] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:33:35] "GET /page HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2018 19:33:35] "GET /spectre.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:33:35] "GET /spectre-exp.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:33:35] "GET /spectre-icons.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:33:35] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:33:35] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:34:30] "GET /page HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2018 19:34:30] "GET /spectre.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:34:30] "GET /spectre-exp.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:34:30] "GET /spectre-icons.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:34:30] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:34:30] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:40:48] "GET /page HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2018 19:40:48] "GET /spectre.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:40:48] "GET /spectre-exp.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:40:48] "GET /spectre-icons.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:40:48] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:40:48] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:41:27] "GET /page HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2018 19:41:27] "GET /spectre.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:41:27] "GET /spectre-exp.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:41:27] "GET /spectre-icons.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:41:27] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:41:28] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:42:21] "GET /page HTTP/1.1" 200 -
# 127.0.0.1 - - [08/Sep/2018 19:42:21] "GET /spectre.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:42:21] "GET /spectre-exp.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:42:21] "GET /spectre-icons.min.css HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:42:21] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [08/Sep/2018 19:42:21] "GET /js/bootstrap.min.js HTTP/1.1" 404 -
